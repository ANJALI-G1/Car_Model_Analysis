# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df=pd.read_csv("Cars.csv")

# %%
df.head() #first five data row
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
print(df.shape)
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#setting up name column as index
df.set_index('name')
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
# [398 rows x 8 columns]

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
df["mpg"].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %%
df["mpg"].nunique() #number of unique values
# Out:
# 129

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
# Creating the new metric column
df['hp_per_weight'] = df['horsepower'] / df['weight']

# %%
df.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name  hp_per_weight
# 0          70    usa  chevrolet chevelle malibu       0.037100
# 1          70    usa          buick skylark 320       0.044679

# %%
#setting as index
df.set_index("hp_per_weight",inplace=True)
df.head(2)
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# hp_per_weight
# 0.037100       18.0          8         307.0       130.0    3504
# 0.044679       15.0          8         350.0       165.0    3693
#
#                acceleration  model_year origin                       name
# hp_per_weight
# 0.037100               12.0          70    usa  chevrolet chevelle malibu
# 0.044679               11.5          70    usa          buick skylark 320

# %%
df.reset_index(inplace=True)  # Brings 'name' back as a column

# %%
df.head(2)
# Out:
#    hp_per_weight   mpg  cylinders  displacement  horsepower  weight  \
# 0       0.037100  18.0          8         307.0       130.0    3504
# 1       0.044679  15.0          8         350.0       165.0    3693
#
#    acceleration  model_year origin                       name
# 0          12.0          70    usa  chevrolet chevelle malibu
# 1          11.5          70    usa          buick skylark 320

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %%
df2=pd.read_csv("Cars.csv")

# %%
df2.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
df2['horsepower'].max()
# Out:
# 230.0

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
count=(df2['mpg']>=35).sum()
count
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
filtered_df=df[(df2['horsepower']>100 )& (df2['weight']<3000)]
filtered_df
# Out:
#      hp_per_weight   mpg  cylinders  displacement  horsepower  weight  \
# 23        0.050582  26.0          4         121.0       113.0    2234
# 45        0.037137  18.0          6         258.0       110.0    2962
# 76        0.038186  18.0          4         121.0       112.0    2933
# 113       0.043285  21.0          6         155.0       107.0    2472
# 120       0.039052  19.0          4         121.0       112.0    2868
# 122       0.041353  24.0          4         121.0       110.0    2660
# 123       0.043463  20.0          6         156.0       122.0    2807
# 180       0.043055  25.0          4         121.0       115.0    2671
# 210       0.036860  19.0          6         156.0       108.0    2930
# 242       0.042308  21.5          4         121.0       110.0    2600
# 243       0.040441  21.5          3          80.0       110.0    2720
# 271       0.038251  23.2          4         156.0       105.0    2745
# 274       0.036396  20.3          5         131.0       103.0    2830
# 276       0.041145  21.6          4         121.0       115.0    2795
# 306       0.044316  28.8          6         173.0       115.0    2595
# 307       0.042593  26.8          6         173.0       115.0    2700
# 323       0.037500  27.9          4         156.0       105.0    2800
# 333       0.045361  32.7          6         168.0       132.0    2910
# 341       0.040367  23.5          6         173.0       110.0    2725
# 361       0.040000  25.4          6         168.0       116.0    2900
# 362       0.040956  24.2          6         146.0       120.0    2930
# 386       0.037351  25.0          6         181.0       110.0    2945
# 389       0.039506  22.0          6         232.0       112.0    2835
#
#      acceleration  model_year  origin                        name
# 23           12.5          70  europe                    bmw 2002
# 45           13.5          71     usa  amc hornet sportabout (sw)
# 76           14.5          72  europe             volvo 145e (sw)
# 113          14.0          73     usa            mercury capri v6
# 120          15.5          73  europe                 volvo 144ea
# 122          14.0          73  europe                   saab 99le
# 123          13.5          73   japan              toyota mark ii
# 180          13.5          75  europe                   saab 99le
# 210          15.5          76   japan              toyota mark ii
# 242          12.8          77  europe                    bmw 320i
# 243          13.5          77   japan                  mazda rx-4
# 271          16.7          78     usa            plymouth sapporo
# 274          15.9          78  europe                   audi 5000
# 276          15.7          78  europe                  saab 99gle
# 306          11.3          79     usa          chevrolet citation
# 307          12.9          79     usa   oldsmobile omega brougham
# 323          14.4          80     usa                  dodge colt
# 333          11.4          80   japan               datsun 280-zx
# 341          12.6          81     usa          chevrolet citation
# 361          12.6          81   japan             toyota cressida
# 362          13.8          81   japan           datsun 810 maxima
# 386          16.4          82     usa       buick century limited
# 389          14.7          82     usa              ford granada l

# %%
most_common_origin = filtered_df['origin'].value_counts().idxmax()
most_common_origin
# Out:
# 'usa'

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
japan_df=df[(df2['origin']=='japan')]
japan_df
# Out:
#      hp_per_weight   mpg  cylinders  displacement  horsepower  weight  \
# 14        0.040051  24.0          4         113.0        95.0    2372
# 18        0.041315  27.0          4          97.0        88.0    2130
# 29        0.041315  27.0          4          97.0        88.0    2130
# 31        0.042639  25.0          4         113.0        95.0    2228
# 53        0.036661  31.0          4          71.0        65.0    1773
# ..             ...   ...        ...           ...         ...     ...
# 382       0.031180  34.0          4         108.0        70.0    2245
# 383       0.034097  38.0          4          91.0        67.0    1965
# 384       0.034097  32.0          4          91.0        67.0    1965
# 385       0.033584  38.0          4          91.0        67.0    1995
# 390       0.036023  32.0          4         144.0        96.0    2665
#
#      acceleration  model_year origin                   name
# 14           15.0          70  japan  toyota corona mark ii
# 18           14.5          70  japan           datsun pl510
# 29           14.5          71  japan           datsun pl510
# 31           14.0          71  japan          toyota corona
# 53           19.0          71  japan    toyota corolla 1200
# ..            ...         ...    ...                    ...
# 382          16.9          82  japan         toyota corolla
# 383          15.0          82  japan            honda civic
# 384          15.7          82  japan     honda civic (auto)
# 385          16.2          82  japan          datsun 310 gx
# 390          13.9          82  japan       toyota celica gt
#
# [79 rows x 10 columns]

# %%
#calculating mean
avg=round(japan_df['acceleration'].mean(),2)
avg
# Out:
# 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
highest_mpg_year = df2.groupby('model_year')['mpg'].mean().idxmax()
highest_mpg_year
# Out:
# 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
#first calculate those cars which have mpg above median
median_mpg=df2['mpg'].median()
median_mpg
# Out:
# 23.0

# %%
df_above_median_mpg=df2[df2['mpg']>median_mpg]
df_above_median_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                          name
# 14           70   japan         toyota corona mark ii
# 18           70   japan                  datsun pl510
# 19           70  europe  volkswagen 1131 deluxe sedan
# 20           70  europe                   peugeot 504
# 21           70  europe                   audi 100 ls
# ..          ...     ...                           ...
# 393          82     usa               ford mustang gl
# 394          82  europe                     vw pickup
# 395          82     usa                 dodge rampage
# 396          82     usa                   ford ranger
# 397          82     usa                    chevy s-10
#
# [191 rows x 9 columns]

# %%
# Calculate the horsepower-to-weight ratio
df_above_median_mpg['hp_per_weight'] = df_above_median_mpg['horsepower'] / df_above_median_mpg['weight']

# Find the car(s) with the highest ratio
best_ratio_cars = df_above_median_mpg.loc[df_above_median_mpg['hp_per_weight'].idxmax()]

print(best_ratio_cars)
# Out:
# mpg                  26.0
# cylinders               4
# displacement        121.0
# horsepower          113.0
# weight               2234
# acceleration         12.5
# model_year             70
# origin             europe
# name             bmw 2002
# hp_per_weight    0.050582
# Name: 23, dtype: object
# C:\Users\anjal\AppData\Local\Temp\ipykernel_8608\3705441963.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_above_median_mpg['hp_per_weight'] = df_above_median_mpg['horsepower'] / df_above_median_mpg['weight']

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
mpg_trends=df2.groupby(['model_year','origin'])['mpg'].mean().reset_index()
mpg_trends
# Out:
#     model_year  origin        mpg
# 0           70  europe  25.200000
# 1           70   japan  25.500000
# 2           70     usa  15.272727
# 3           71  europe  28.750000
# 4           71   japan  29.500000
# 5           71     usa  18.100000
# 6           72  europe  22.000000
# 7           72   japan  24.200000
# 8           72     usa  16.277778
# 9           73  europe  24.000000
# 10          73   japan  20.000000
# 11          73     usa  15.034483
# 12          74  europe  27.000000
# 13          74   japan  29.333333
# 14          74     usa  18.333333
# 15          75  europe  24.500000
# 16          75   japan  27.500000
# 17          75     usa  17.550000
# 18          76  europe  24.250000
# 19          76   japan  28.000000
# 20          76     usa  19.431818
# 21          77  europe  29.250000
# 22          77   japan  27.416667
# 23          77     usa  20.722222
# 24          78  europe  24.950000
# 25          78   japan  29.687500
# 26          78     usa  21.772727
# 27          79  europe  30.450000
# 28          79   japan  32.950000
# 29          79     usa  23.478261
# 30          80  europe  37.288889
# 31          80   japan  35.400000
# 32          80     usa  25.914286
# 33          81  europe  31.575000
# 34          81   japan  32.958333
# 35          81     usa  27.530769
# 36          82  europe  40.000000
# 37          82   japan  34.888889
# 38          82     usa  29.450000

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=mpg_trends,x='model_year',y='mpg',marker='o')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=mpg_trends,x='model_year',y='mpg',marker='o')
plt.title("Evolution of Average MPG Over the Years by Origin")
plt.xlabel("Year")
plt.ylabel("Average MPG")
plt.legend(title="Origin")
plt.grid(True)


plt.show()
# Out:
# C:\Users\anjal\AppData\Local\Temp\ipykernel_8608\888210764.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Origin")

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
plt.figure(figsize=(10,6))
sns.scatterplot(data=df2 ,x='horsepower',y='weight',hue='origin',size='mpg',palette='coolwarm', hue_order=['japan','europe','usea'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='horsepower', y='weight', hue='origin', size='mpg', palette='coolwarm', hue_order=['japan', 'europe', 'usa'])


plt.title("Horsepower vs. Weight: Vehicle Distribution by Origin and MPG")
plt.xlabel("Horsepower")
plt.ylabel("Weight")
plt.legend(title="Origin")
plt.grid(True)

plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here

#step 1:Identifying cars that come in multiple year
car_counts=df2.groupby('name').size()
print(car_counts)
# Out:
# name
# amc ambassador brougham    1
# amc ambassador dpl         1
# amc ambassador sst         1
# amc concord                2
# amc concord d/l            1
#                           ..
# vw dasher (diesel)         1
# vw pickup                  1
# vw rabbit                  2
# vw rabbit c (diesel)       1
# vw rabbit custom           1
# Length: 305, dtype: int64

# %%
multi_year_car=car_counts[car_counts>1].index
multi_year_car
# Out:
# Index(['amc concord', 'amc gremlin', 'amc hornet', 'amc matador',
#        'amc matador (sw)', 'audi 100ls', 'buick century',
#        'buick estate wagon (sw)', 'buick skylark', 'chevrolet caprice classic',
#        'chevrolet chevelle malibu', 'chevrolet chevelle malibu classic',
#        'chevrolet chevette', 'chevrolet citation', 'chevrolet impala',
#        'chevrolet malibu', 'chevrolet monte carlo landau', 'chevrolet nova',
#        'chevrolet vega', 'datsun 210', 'datsun 710', 'datsun pl510',
#        'dodge aspen', 'dodge colt', 'fiat 128', 'ford country squire (sw)',
#        'ford galaxie 500', 'ford gran torino', 'ford gran torino (sw)',
#        'ford ltd', 'ford maverick', 'ford pinto', 'honda accord',
#        'honda civic', 'honda civic cvcc', 'mazda 626',
#        'oldsmobile cutlass salon brougham', 'opel 1900', 'opel manta',
#        'peugeot 504', 'plymouth duster', 'plymouth fury iii',
#        'plymouth reliant', 'plymouth valiant', 'pontiac catalina',
#        'pontiac phoenix', 'saab 99le', 'subaru', 'subaru dl', 'toyota corolla',
#        'toyota corolla 1200', 'toyota corona', 'toyota mark ii',
#        'volkswagen dasher', 'volkswagen rabbit', 'vw rabbit'],
#       dtype='object', name='name')

# %%
consistent_cars = df2[df2['name'].isin(multi_year_car)].groupby('name').agg(
    std_mpg=('mpg', 'std'), 
    count_years=('model_year', 'count'), 
    avg_mpg=('mpg', 'mean')
)
consistent_cars
# Out:
#                                     std_mpg  count_years    avg_mpg
# name
# amc concord                        3.464823            2  21.850000
# amc gremlin                        1.290994            4  19.500000
# amc hornet                         2.136001            4  19.375000
# amc matador                        1.483240            5  15.700000
# amc matador (sw)                   0.707107            2  14.500000
# audi 100ls                         2.121320            2  21.500000
# buick century                      3.818377            2  19.700000
# buick estate wagon (sw)            2.050610            2  15.450000
# buick skylark                      4.313351            2  23.550000
# chevrolet caprice classic          2.466441            3  15.833333
# chevrolet chevelle malibu          0.707107            2  17.500000
# chevrolet chevelle malibu classic  1.060660            2  16.750000
# chevrolet chevette                 1.293574            4  30.400000
# chevrolet citation                 2.857155            3  26.766667
# chevrolet impala                   1.414214            4  13.000000
# chevrolet malibu                   5.303301            2  16.750000
# chevrolet monte carlo landau       2.616295            2  17.350000
# chevrolet nova                     3.511885            3  18.333333
# chevrolet vega                     2.645751            3  22.000000
# datsun 210                         6.363961            2  36.300000
# datsun 710                         5.656854            2  28.000000
# datsun pl510                       0.000000            2  27.000000
# dodge aspen                        0.353553            2  18.850000
# dodge colt                         1.126943            3  27.300000
# fiat 128                           3.535534            2  26.500000
# ford country squire (sw)           1.767767            2  14.250000
# ford galaxie 500                   0.577350            3  14.333333
# ford gran torino                   1.040833            3  14.833333
# ford gran torino (sw)              0.707107            2  13.500000
# ford ltd                           0.707107            2  13.500000
# ford maverick                      3.420526            5  19.800000
# ford pinto                         3.638910            6  22.916667
# honda accord                       2.545584            2  34.200000
# honda civic                        7.094599            3  31.666667
# honda civic cvcc                   2.192031            2  34.550000
# mazda 626                          0.212132            2  31.450000
# oldsmobile cutlass salon brougham  2.828427            2  21.900000
# opel 1900                          2.121320            2  26.500000
# opel manta                         1.414214            2  25.000000
# peugeot 504                        3.484729            4  23.550000
# plymouth duster                    1.527525            3  21.666667
# plymouth fury iii                  0.577350            3  14.333333
# plymouth reliant                   1.979899            2  28.600000
# plymouth valiant                   2.828427            2  20.000000
# pontiac catalina                   1.154701            3  14.666667
# pontiac phoenix                    4.596194            2  30.250000
# saab 99le                          0.707107            2  24.500000
# subaru                             4.454773            2  29.150000
# subaru dl                          2.687006            2  31.900000
# toyota corolla                     2.516347            5  31.120000
# toyota corolla 1200                0.707107            2  31.500000
# toyota corona                      3.119161            4  26.875000
# toyota mark ii                     0.707107            2  19.500000
# volkswagen dasher                  2.929733            3  27.166667
# volkswagen rabbit                  0.353553            2  29.250000
# vw rabbit                          8.838835            2  35.250000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
